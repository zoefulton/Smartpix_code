# %%
humidity_file = open('/Users/zoefulton/Downloads/Smartpix_files/Smartpix_code/test_20260326.txt', 'r')

# %% [markdown]
# ### Functions to turn off and on switch 1 (can change based on switch)

# %%
#functions to turn on and off switch 1 based on humidity value
import serial
import serial.tools.list_ports

humidity = 30 # Example humidity value, replace with actual reading from sensor

ports = serial.tools.list_ports.comports()

def on_switch_1():
    ser = serial.Serial("/dev/cu.usbserial-11210", 9600, timeout=1) # will need to change device name on lab computer
    data = bytearray([0xA0, 0x01, 0x01, 0xA2])
    ser.write(data)
    return "Switch 1 ON"

def off_switch_1():
    ser = serial.Serial("/dev/cu.usbserial-11210", 9600, timeout=1)
    data = bytearray([0xA0, 0x01, 0x00, 0xA1])
    ser.write(data)
    return "Switch 1 OFF"

if humidity >= 50:
    off_switch_1()
    print("Humidity has reached threshold level, turning off electronics.")
